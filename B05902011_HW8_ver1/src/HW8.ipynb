# %%
import iprocess as ip
from PIL import Image
import numpy as np
import statistics as st

# %%
im = Image.open("lena.bmp").convert('L')

# %%
img = np.array(im)
med5x5 = ip.medium_filter(img, 5).result

# %%
Image.fromarray(img, mode="L")
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x10B2E4650>

# %%
Image.fromarray(med5x5, mode="L")
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x10B2E4B10>

# %%
from math import log
from math import sqrt
def SNR(origin_img, noice_img):
    normalize_origin = origin_img / 255
    normalize_noice = noice_img / 255
    dim = normalize_origin.size
    
    mu = np.sum(normalize_origin, axis=None) / dim
    VS = np.sum(np.square(normalize_origin - mu), axis=None) / dim
    delta = normalize_noice - normalize_origin
    muN = np.sum(delta, axis=None) / dim
    VN = np.sum(np.square(delta - muN), axis=None) / dim
    return 20*log(sqrt(VS / VN), 10)

# %%
SNR(img, med5x5)
# Out:
# 16.858166751900455

# %%
test = "helloworld.png"
test[:-4]
# Out:
# 'helloworld'

# %%
test[-4:]
# Out:
# '.png'
